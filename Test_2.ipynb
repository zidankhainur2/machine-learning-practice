# %% [markdown]
# <a href="https://colab.research.google.com/github/zidankhainur2/machine-learning-practice/blob/main/Test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("/content/test_image.jpg")  #this is a numpy array
print(type(img))
print(img)

print(img.shape)

plt.imshow(img)
plt.colorbar()   #Puts a color bar next to the image.
# Out:
# <class 'numpy.ndarray'>
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 34  24  22]
#   [ 34  24  22]
#   [ 32  22  20]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 36  26  24]
#   [ 35  25  23]
#   [ 34  24  22]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 36  26  24]
#   [ 35  25  23]
#   [ 33  23  21]]
#
#  ...
#
#  [[102  80  59]
#   [100  78  57]
#   [ 97  74  56]
#   ...
#   [176 147 113]
#   [176 147 113]
#   [177 148 114]]
#
#  [[103  81  60]
#   [ 95  73  52]
#   [ 93  70  52]
#   ...
#   [175 146 112]
#   [176 147 113]
#   [177 148 114]]
#
#  [[104  82  59]
#   [ 93  71  50]
#   [ 93  71  50]
#   ...
#   [175 146 112]
#   [175 149 114]
#   [176 150 115]]]
# (3240, 4320, 3)
